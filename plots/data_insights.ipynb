# %% [markdown]
# # Air Pollution Data Berlin

# %%
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_ride_1 = pd.read_csv('../data/ride1.csv')

df_ride_1
# Out:
#                             Time        lat       long                d  \
# 0     2020-12-08T12:03:02.868654  52.549842  13.372655   2christianWall
# 1     2020-12-08T12:03:03.868215  52.549867  13.372698   2christianWall
# 2     2020-12-08T12:03:04.879451  52.549985  13.372802   2christianWall
# 3     2020-12-08T12:03:05.892729  52.550028  13.372808   2christianWall
# 4     2020-12-08T12:03:06.903448  52.549972  13.372813   2christianWall
# ...                          ...        ...        ...              ...
# 1281  2020-12-08T12:27:45.884845  52.550732  13.371427             none
# 1282  2020-12-08T12:27:46.901667  52.550733  13.371448             none
# 1283  2020-12-08T12:27:47.935312  52.550737  13.371470   2christianWall
# 1284  2020-12-08T12:27:49.968771  52.550747  13.371535   2christianWall
# 1285  2020-12-08T12:27:50.987295  52.550748  13.371558   2christianWall
#
#      Direction         f  PM1.0  PM2.5  PM10.0  0.3μm  0.5μm  1.0μm  2.5μm  \
# ...

# %%
df_ride_2 = pd.read_csv('../data/ride2.csv')
df_ride_3 = pd.read_csv('../data/ride3.csv')
df_ride_4 = pd.read_csv('../data/ride4.csv')
df_ride_5 = pd.read_csv('../data/ride5.csv')
df_ride_6 = pd.read_csv('../data/ride6.csv')
df_ride_7 = pd.read_csv('../data/ride7.csv')

# %% [markdown]
# ## Plots for each ride

# %%
df_ride_1.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 1')
df_ride_2.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 2')
df_ride_3.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 3')
df_ride_4.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 4')
df_ride_5.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 5')
df_ride_6.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 6')
df_ride_7.plot(kind = 'line', y = ['PM1.0', 'PM2.5', 'PM10.0'], title = 'Ride 7')
# Out:
# <AxesSubplot:title={'center':'Ride 7'}>

# %% [markdown]
# ## Plots for each PM (particulate matter)

# %%
plt.plot(df_ride_1.index, df_ride_1['PM1.0'], label='Ride 1')
plt.plot(df_ride_2.index, df_ride_2['PM1.0'], label='Ride 2')
plt.plot(df_ride_3.index, df_ride_3['PM1.0'], label='Ride 3')
plt.plot(df_ride_4.index, df_ride_4['PM1.0'], label='Ride 4')
plt.plot(df_ride_5.index, df_ride_5['PM1.0'], label='Ride 5')
plt.plot(df_ride_6.index, df_ride_6['PM1.0'], label='Ride 6')
plt.plot(df_ride_7.index, df_ride_7['PM1.0'], label='Ride 7')
plt.legend()
plt.title('PM 1.0')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pm1 = pd.concat([df_ride_1['PM1.0'],df_ride_2['PM1.0'],df_ride_3['PM1.0'],df_ride_4['PM1.0'],df_ride_5['PM1.0'],df_ride_6['PM1.0'],df_ride_7['PM1.0']])
pm1.describe()
# Out:
# count    12756.000000
# mean        23.712763
# std         12.000515
# min          1.000000
# 25%         15.000000
# 50%         21.000000
# 75%         31.000000
# max         86.000000
# Name: PM1.0, dtype: float64

# %%
pm1.plot.box()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df_ride_1.index, df_ride_1['PM2.5'], label='Ride 1')
plt.plot(df_ride_2.index, df_ride_2['PM2.5'], label='Ride 2')
plt.plot(df_ride_3.index, df_ride_3['PM2.5'], label='Ride 3')
plt.plot(df_ride_4.index, df_ride_4['PM2.5'], label='Ride 4')
plt.plot(df_ride_5.index, df_ride_5['PM2.5'], label='Ride 5')
plt.plot(df_ride_6.index, df_ride_6['PM2.5'], label='Ride 6')
plt.plot(df_ride_7.index, df_ride_7['PM2.5'], label='Ride 7')
plt.legend()
plt.title('PM 2.5')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pm2_5 = pd.concat([df_ride_1['PM2.5'],df_ride_2['PM2.5'],df_ride_3['PM2.5'],df_ride_4['PM2.5'],df_ride_5['PM2.5'],df_ride_6['PM2.5'],df_ride_7['PM2.5']])
pm2_5.describe()
# Out:
# count    12756.000000
# mean        41.666510
# std         23.915675
# min          3.000000
# 25%         22.000000
# 50%         36.000000
# 75%         59.000000
# max        265.000000
# Name: PM2.5, dtype: float64

# %%
pm2_5.plot.box()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df_ride_1.index, df_ride_1['PM10.0'], label='Ride 1')
plt.plot(df_ride_2.index, df_ride_2['PM10.0'], label='Ride 2')
plt.plot(df_ride_3.index, df_ride_3['PM10.0'], label='Ride 3')
plt.plot(df_ride_4.index, df_ride_4['PM10.0'], label='Ride 4')
plt.plot(df_ride_5.index, df_ride_5['PM10.0'], label='Ride 5')
plt.plot(df_ride_6.index, df_ride_6['PM10.0'], label='Ride 6')
plt.plot(df_ride_7.index, df_ride_7['PM10.0'], label='Ride 7')
plt.legend()
plt.title('PM 10.0')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pm10 = pd.concat([df_ride_1['PM10.0'],df_ride_2['PM10.0'],df_ride_3['PM10.0'],df_ride_4['PM10.0'],df_ride_5['PM10.0'],df_ride_6['PM10.0'],df_ride_7['PM10.0']])
pm10.describe()
# Out:
# count    12756.000000
# mean        48.102148
# std         30.634044
# min          4.000000
# 25%         25.000000
# 50%         41.000000
# 75%         69.000000
# max        273.000000
# Name: PM10.0, dtype: float64

# %%
pm10.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Modify PM columns so that areas are disjoint and plot

# %%
dataframes = [df_ride_1, df_ride_2, df_ride_3, df_ride_4, df_ride_5, df_ride_6, df_ride_7]

for df in dataframes:
    df['1.0'] = df['PM1.0']
    df['2.5'] = df['PM2.5'] - df['PM1.0']
    df['10.0'] = df['PM10.0'] - df['PM2.5']

# %%
df_ride_1.plot(kind = 'line', y = ['1.0', '2.5', '10.0'], title = 'Ride 1 Disjoint PM Values')
# Out:
# <AxesSubplot:title={'center':'Ride 1 Disjoint PM Values'}>

# %%
df_ride_6.plot(kind = 'line', y = ['1.0', '2.5', '10.0'], title = 'Ride 6 Disjoint PM Values')
# Out:
# <AxesSubplot:title={'center':'Ride 6 Disjoint PM Values'}>

# %%
"""
# safe tables with new disjoint columns
df_ride_1.to_csv('../data/ride1.csv', index=False)
df_ride_2.to_csv('../data/ride2.csv', index=False)
df_ride_3.to_csv('../data/ride3.csv', index=False)
df_ride_4.to_csv('../data/ride4.csv', index=False)
df_ride_5.to_csv('../data/ride5.csv', index=False)
df_ride_6.to_csv('../data/ride6.csv', index=False)
df_ride_7.to_csv('../data/ride7.csv', index=False)
"""
# Out:
# "\n# safe tables with new disjoint columns\ndf_ride_1.to_csv('../data/ride1.csv', index=False)\ndf_ride_2.to_csv('../data/ride2.csv', index=False)\ndf_ride_3.to_csv('../data/ride3.csv', index=False)\ndf_ride_4.to_csv('../data/ride4.csv', index=False)\ndf_ride_5.to_csv('../data/ride5.csv', index=False)\ndf_ride_6.to_csv('../data/ride6.csv', index=False)\ndf_ride_7.to_csv('../data/ride7.csv', index=False)\n"

# %%
plt.plot(df_ride_1.index, df_ride_1['1.0'], label='Ride 1')
plt.plot(df_ride_2.index, df_ride_2['1.0'], label='Ride 2')
plt.plot(df_ride_3.index, df_ride_3['1.0'], label='Ride 3')
plt.plot(df_ride_4.index, df_ride_4['1.0'], label='Ride 4')
plt.plot(df_ride_5.index, df_ride_5['1.0'], label='Ride 5')
plt.plot(df_ride_6.index, df_ride_6['1.0'], label='Ride 6')
plt.plot(df_ride_7.index, df_ride_7['1.0'], label='Ride 7')
plt.legend()
plt.title('disjoint PM 1.0')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pm1_disjoint = pd.concat([df_ride_1['1.0'],df_ride_2['1.0'],df_ride_3['1.0'],df_ride_4['1.0'],df_ride_5['1.0'],df_ride_6['1.0'],df_ride_7['1.0']])
pm1_disjoint.plot.box()
# Out:
# <AxesSubplot:>

# %%
pm1_disjoint.describe()
# Out:
# count    12756.000000
# mean        23.712763
# std         12.000515
# min          1.000000
# 25%         15.000000
# 50%         21.000000
# 75%         31.000000
# max         86.000000
# Name: 1.0, dtype: float64

# %%
plt.plot(df_ride_1.index, df_ride_1['2.5'], label='Ride 1')
plt.plot(df_ride_2.index, df_ride_2['2.5'], label='Ride 2')
plt.plot(df_ride_3.index, df_ride_3['2.5'], label='Ride 3')
plt.plot(df_ride_4.index, df_ride_4['2.5'], label='Ride 4')
plt.plot(df_ride_5.index, df_ride_5['2.5'], label='Ride 5')
plt.plot(df_ride_6.index, df_ride_6['2.5'], label='Ride 6')
plt.plot(df_ride_7.index, df_ride_7['2.5'], label='Ride 7')
plt.legend()
plt.title('disjoint PM 2.5')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pm2_5_disjoint = pd.concat([df_ride_1['2.5'],df_ride_2['2.5'],df_ride_3['2.5'],df_ride_4['2.5'],df_ride_5['2.5'],df_ride_6['2.5'],df_ride_7['2.5']])
pm2_5_disjoint.plot.box()
# Out:
# <AxesSubplot:>

# %%
pm2_5_disjoint.describe()
# Out:
# count    12756.000000
# mean        17.953747
# std         12.747645
# min          1.000000
# 25%          7.000000
# 50%         15.000000
# 75%         28.000000
# max        181.000000
# Name: 2.5, dtype: float64

# %%
plt.plot(df_ride_1.index, df_ride_1['10.0'], label='Ride 1')
plt.plot(df_ride_2.index, df_ride_2['10.0'], label='Ride 2')
plt.plot(df_ride_3.index, df_ride_3['10.0'], label='Ride 3')
plt.plot(df_ride_4.index, df_ride_4['10.0'], label='Ride 4')
plt.plot(df_ride_5.index, df_ride_5['10.0'], label='Ride 5')
plt.plot(df_ride_6.index, df_ride_6['10.0'], label='Ride 6')
plt.plot(df_ride_7.index, df_ride_7['10.0'], label='Ride 7')
plt.legend()
plt.title('disjoint PM 10.0')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pm10_disjoint = pd.concat([df_ride_1['10.0'],df_ride_2['10.0'],df_ride_3['10.0'],df_ride_4['10.0'],df_ride_5['10.0'],df_ride_6['10.0'],df_ride_7['10.0']])
pm10_disjoint.plot.box()
# Out:
# <AxesSubplot:>

# %%
pm10_disjoint.describe()
# Out:
# count    12756.000000
# mean         6.435638
# std         10.414175
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          9.000000
# max        156.000000
# Name: 10.0, dtype: float64

# %% [markdown]
# ## Raincloud Plots for PM columns
#
# The following code is inspired by https://wellcomeopenresearch.org/articles/4-63

# %%
import ptitprince as pt
import seaborn as sns
import matplotlib.collections as clt

# %%
pm1 = pm1.to_frame()
pm1['group'] = "PM1_Values"

pm2_5 = pm2_5.to_frame()
pm2_5['group'] = "PM2.5_Values"

pm10 = pm10.to_frame()
pm10['group'] = "PM10_Values"

pm1.columns = ['value', 'group']
pm2_5.columns = ['value', 'group']
pm10.columns = ['value', 'group']

frames = [pm1, pm2_5, pm10]
df_pm = pd.concat(frames)

df_pm
# Out:
#       value        group
# 0        29   PM1_Values
# 1        30   PM1_Values
# 2        30   PM1_Values
# 3        30   PM1_Values
# 4        30   PM1_Values
# ...     ...          ...
# 2083     40  PM10_Values
# 2084     40  PM10_Values
# 2085     41  PM10_Values
# 2086     40  PM10_Values
# 2087     40  PM10_Values
#
# [38268 rows x 2 columns]

# %%
# plotting the clouds
sns.set(style="whitegrid",font_scale=2)
f, ax = plt.subplots(figsize=(20, 10))
dy="group"; dx="value"; ort="h"; pal = "Set1"
ax=pt.half_violinplot( x = dx, y = dy, data = df_pm, palette = pal,
       bw = .2, cut = 0.,scale = "area", width = .6, inner = None,
      orient = ort)

# adding the rain and the jitter
ax=sns.stripplot( x = dx, y = dy, data = df_pm, palette = pal, 
     edgecolor = "white",size = 3, jitter = 1, zorder = 0,
     orient = ort)

#adding the boxplot with quartiles
ax=sns.boxplot( x = dx, y = dy, data = df_pm, color = "black", 
       width = .15, zorder = 10, showcaps = True,
       boxprops = {'facecolor':'none', "zorder":10}, showfliers=True,
       whiskerprops = {'linewidth':2, "zorder":10},
       saturation = 1, orient = ort)

# %% [markdown]
# ## Raincloud Plots for disjoint PM columns
#
# The following code is inspired by https://wellcomeopenresearch.org/articles/4-63

# %%
pm1_disjoint = pm1_disjoint.to_frame()
pm1_disjoint['group'] = "PM1"

pm2_5_disjoint = pm2_5_disjoint.to_frame()
pm2_5_disjoint['group'] = "PM2.5"

pm10_disjoint = pm10_disjoint.to_frame()
pm10_disjoint['group'] = "PM10"

pm1_disjoint.columns = ['value', 'group']
pm2_5_disjoint.columns = ['value', 'group']
pm10_disjoint.columns = ['value', 'group']

frames = [pm1_disjoint, pm2_5_disjoint, pm10_disjoint]
df_disjoint = pd.concat(frames)

df_disjoint
# Out:
#       value group
# 0        29   PM1
# 1        30   PM1
# 2        30   PM1
# 3        30   PM1
# 4        30   PM1
# ...     ...   ...
# 2083      6  PM10
# 2084      5  PM10
# 2085      6  PM10
# 2086      6  PM10
# 2087      5  PM10
#
# [38268 rows x 2 columns]

# %%
# plotting the clouds
sns.set(style="whitegrid",font_scale=2)
f, ax = plt.subplots(figsize=(20, 10))
dy="group"; dx="value"; ort="h"; pal = "Set1"
ax=pt.half_violinplot( x = dx, y = dy, data = df_disjoint, palette = pal,
       bw = .2, cut = 0.,scale = "area", width = .6, inner = None,
      orient = ort)

# adding the rain and the jitter
ax=sns.stripplot( x = dx, y = dy, data = df_disjoint, palette = pal, 
     edgecolor = "white",size = 3, jitter = 1, zorder = 0,
     orient = ort)

#adding the boxplot with quartiles
ax=sns.boxplot( x = dx, y = dy, data = df_disjoint, color = "black", 
       width = .15, zorder = 10, showcaps = True,
       boxprops = {'facecolor':'none', "zorder":10}, showfliers=True,
       whiskerprops = {'linewidth':2, "zorder":10},
       saturation = 1, orient = ort)
